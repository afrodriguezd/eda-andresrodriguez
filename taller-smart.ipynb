# %%
Problema
Empresa de moda, enfrenta imprecisiones en la planeación de sus colecciones debido a un proceso de estimación de demanda basado principalmente en análisis cualitativo y criterios subjetivos
Hallazgos
1.	Inexactitud en producción de inventario por línea de producto
2.	Distribución inadecuada del inventario entre las tiendas
3.	Sobre stock o quiebre de inventario en algunas líneas y/o tiendas
4.	Pérdida de ventas por falta de stock
5.	Costos adicionales por exceso de inventario
6.	Ineficiencia en la utilización de recursos de producción y logística
Indicador a mejorar:
Precisión en la previsión de la demanda
Justificación
Se puede abordar desde el análisis exploratorio de datos y modelos cuantitativos para mejorar la precisión en la previsión de la demanda y optimizar la planeación de inventario
Beneficios:
1.	Reducir el exceso de inventario y los faltantes
2.	Mejorar la asignación de inventario entre tiendas
3.	Incrementar las ventas al tener el producto correcto en el lugar adecuado
Datos disponibles:
•	Históricos de ventas
•	Producción de colecciones anteriores
•	Datos externos (indicadores económicos, clima)
Pregunta SMART
¿Cómo reducir el error en la previsión de demanda de productos por línea y tienda en un 20% para las próximas 4 colecciones, utilizando modelos predicción y optimización, con el fin de optimizar la planificación de inventario y reducir los casos de sobre stock y faltantes?
